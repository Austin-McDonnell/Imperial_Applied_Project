# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import os
import sys
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import json
import requests
import urllib.request

# %%
html_file_path = r'C:\Users\austi\Documents\Github_Repos\Imperial_Applied_Project\Testing_HTML'
html_files = os.listdir(html_file_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-d4a2ab32212b> in <module>
#       1 html_file_path = r'C:\Users\austi\Documents\Github_Repos\Imperial_Applied_Project\Testing_HTML'
# ----> 2 html_files = os.listdir(html_file_path)
#
# NameError: name 'os' is not defined

# %%
html_files
# Out:
# ['48126.html', 'pop_up_window.html']

# %%
with open(html_file_path + '//'+ html_files[0], encoding='utf8') as fp:
    soup = BeautifulSoup(fp)
fp.close()

# %%
soup.body
# Out:
# <body class="actionbar-inline srp-page-container nav-full-width zsg-layout_full responsive-search-page hide-top-nav-gleam bdp-double-scroll-layout tengage wide znav-search-bar">
# ...

# %%
homes_on_page = soup.find(name='ul', class_='photo-cards photo-cards_wow')

# %%
num_homes = 0
homes_on_page.find_all(name='li')
# Out:
# [<li><script type="application/ld+json">{"@type":"SingleFamilyResidence","@context":"http://schema.org","name":"7925 Appoline St, Dearborn, MI 48126","floorSize":{"@type":"QuantitativeValue","@context":"http://schema.org","value":"2,062"},"numberOfRooms":3,"address":{"@type":"PostalAddress","@context":"http://schema.org","streetAddress":"7925 Appoline St","addressLocality":"Dearborn","addressRegion":"MI","postalCode":"48126"},"geo":{"@type":"GeoCoordinates","@context":"http://schema.org","latitude":42.351061,"longitude":-83.168797},"url":"/homedetails/7925-Appoline-St-Dearborn-MI-48126/160182034_zpid/"}</script><article class="list-card list-card_not-saved" data-index="0" id="zpid_160182034" role="presentation"><a aria-label="House for sale, 7925 Appoline St, Dearborn, MI 48126, $189,900" class="list-card-link list-card-info" href="https://www.zillow.com/homedetails/7925-Appoline-St-Dearborn-MI-48126/160182034_zpid/"><h3 class="list-card-addr">7925 Appoline St, Dearborn, MI 48126</h3
# ...
